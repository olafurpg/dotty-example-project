# %%
with open("build.sbt", "r") as file:
    text = file.read()
    print(text)
# Out:
# lazy val root = project
#   .in(file("."))
#   .settings(
#     name := "dotty-example-project",
#     description := "Example sbt project that compiles using Dotty",
#     version := "0.1.0",
#
#     scalaVersion := "0.15.0-RC1"
#   )
